# %%
import sys
import os
import datetime
import openpyxl
from openpyxl import Workbook
wb = Workbook()
filename = 'C:\\Users\\tan.m.10\\OneDrive - Procter and Gamble\\Python\\Excel\\Book4.xlsx'
wb.save(filename)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-8f0088e44d73> in <module>()
#       7 filename = 'C:\\Users\\tan.m.10\\OneDrive - Procter and Gamble\\Python\\Excel\\Book4.xlsx'
#       8 wb.save(filename)
# ----> 9 get_ipython().run_line_magic('load', 'https://raw.githubusercontent.com/mtan97/Learning-Python/Excel/Creating New Workbook and Editing.ipynb')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2129                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2130             with self.builtin_trap:
# -> 2131                 result = fn(*args,**kwargs)
#    2132             return result
#    2133
#
# <decorator-gen-48> in load(self, arg_s)
#
# ...
